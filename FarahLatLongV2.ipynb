# %%
import pandas as pd
import requests 
import json
import time 
from config import gkey

# %%
test = pd.read_csv("data/NYC_Restaurants.csv")
test = test.astype({"ZIPCODE": str})
address_full = test['BUILDING']+" "+test['STREET'] +" "+ test['ZIPCODE']
test['address_full'] = address_full

# %%
test.head(1)
# Out:
#       CAMIS                    DBA   BORO BUILDING           STREET  ZIPCODE  \
# 0  30075445  MORRIS PARK BAKE SHOP  BRONX     1007  MORRIS PARK AVE  10462.0
#
#         PHONE CUISINE DESCRIPTION INSPECTION DATE  \
# 0  7188924968              Bakery       6/11/2019
#
#                                             ACTION VIOLATION CODE  \
# 0  Violations were cited in the following area(s).            08C
#
#                                VIOLATION DESCRIPTION CRITICAL FLAG  SCORE  \
# 0  Pesticide use not in accordance with label or ...  Not Critical      6
#
#   GRADE GRADE DATE RECORD DATE                   INSPECTION TYPE  \
# 0     A  6/11/2019   6/21/2019  Cycle Inspection / Re-inspection
#
#                    address_full
# 0  1007 MORRIS PARK AVE 10462.0

# %%
unique_address = address_full.unique()

n=100
cities_chunked = [unique_address[i * n:(i + 1) * n] for i in range((len(unique_address) + n - 1) // n )]  
lat = []
long = []
cities = []
address_l = []
geocode_lookup = pd.DataFrame(columns=['Address', 'cities', 'lat', 'long'])
# len(unique_address) # 2210

# %%
for chunk in cities_chunked:
   for index, address in enumerate(chunk): # for address in chunk
        url = f"https://maps.googleapis.com/maps/api/geocode/json?address={address}&key=AIzaSyAqWs__B4XuFrA1PB1CX3PG-k7Au9qbLsw"
        response = requests.get(url).json()
            # extract results
        results = response['results']
        try: 
            address_l.append(address)
            lat.append(results[0]["geometry"]["location"]["lat"])
            long.append(results[0]["geometry"]["location"]["lng"])
            cities.append(results[0]['formatted_address'])
            print(f"Processing Record {index+1}")
#             print(f"Processing Record {index+1} of Set {cities_chunked.index(chunk)+1}| {address}")
        except (KeyError, IndexError):
            address_l.append(address)
            lat.append(0)
            long.append(0)
            cities.append("Error")
            print("Missing field/result... skipping.")
    # sleep for 60 seconds
time.sleep(5)
# Out:
# Processing Record 1
# Processing Record 2
# Missing field/result... skipping.
# Processing Record 4
# Processing Record 5
# Processing Record 6
# Processing Record 7
# Processing Record 8
# Processing Record 9
# Processing Record 10
# Processing Record 11
# Processing Record 12
# Processing Record 13
# Processing Record 14
# Processing Record 15
# Processing Record 16
# Processing Record 17
# Processing Record 18
# Processing Record 19
# Processing Record 20
# Processing Record 21
# Processing Record 22
# Processing Record 23
# Processing Record 24
# Processing Record 25
# Missing field/result... skipping.
# Processing Record 27
# Processing Record 28
# Processing Record 29
# Processing Record 30
# Processing Record 31
# Processing Record 32
# Processing Record 33
# Processing Record 34
# Processing Record 35
# Processing Record 36
# Processing Record 37
# Processing Record 38
# Processing Record 39
# Processing Record 40
# Processing Record 41
# Processing Record 42
# ...

# %%
len(lat)
len(address_l)
len(long)
len(address_l)
# Out:
# 2282

# %%
geocode_lookup['Address']  = address_l
geocode_lookup['lat'] =  lat
geocode_lookup['long'] =  long
geocode_lookup['cities'] = cities
geocode_lookup.to_csv("RestaurantGeoCodes.csv", index = False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-78b2df6c8b9c> in <module>
#       1 geocode_lookup['Address']  = address_l
# ----> 2 geocode_lookup['lat'] =  lat
#       3 geocode_lookup['long'] =  long
#       4 geocode_lookup['cities'] = cities
#       5 geocode_lookup.to_csv("RestaurantGeoCodes.csv", index = False)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3368         else:
#    3369             # set column
# -> 3370             self._set_item(key, value)
#    3371
#    3372     def _setitem_slice(self, key, value):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3443
#    3444         self._ensure_valid_index(value)
# ...
