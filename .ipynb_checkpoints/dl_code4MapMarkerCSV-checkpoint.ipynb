# %%
import pandas as pd
import csv

# %%
test = pd.read_csv("data/Restaurant_Geo_Final.csv")
test.head()
# Out:
#       CAMIS                             DBA       BORO BUILDING  \
# 0  30075445           MORRIS PARK BAKE SHOP      BRONX     1007
# 1  30075445           MORRIS PARK BAKE SHOP      BRONX     1007
# 2  30075445           MORRIS PARK BAKE SHOP      BRONX     1007
# 3  30191841  DJ REYNOLDS PUB AND RESTAURANT  MANHATTAN      351
# 4  30191841  DJ REYNOLDS PUB AND RESTAURANT  MANHATTAN      351
#
#              STREET  ZIPCODE       PHONE CUISINE DESCRIPTION INSPECTION DATE  \
# 0   MORRIS PARK AVE  10462.0  7188924968              Bakery       6/11/2019
# 1   MORRIS PARK AVE  10462.0  7188924968              Bakery       6/11/2019
# 2   MORRIS PARK AVE  10462.0  7188924968              Bakery       6/11/2019
# 3  WEST   57 STREET  10019.0  2122452912               Irish        6/6/2019
# 4  WEST   57 STREET  10019.0  2122452912               Irish        6/6/2019
#
#                                             ACTION  ... SCORE GRADE  \
# ...

# %%
len(test['CAMIS'].unique())
# Out:
# 2354

# %%
test['BORO'].unique()
# Out:
# array(['BRONX', 'MANHATTAN', 'BROOKLYN', 'STATEN ISLAND', 'QUEENS',
#        'Missing'], dtype=object)

# %%
test.columns
# Out:
# Index(['CAMIS', 'DBA', 'BORO', 'BUILDING', 'STREET', 'ZIPCODE', 'PHONE',
#        'CUISINE DESCRIPTION', 'INSPECTION DATE', 'ACTION', 'VIOLATION CODE',
#        'VIOLATION DESCRIPTION', 'CRITICAL FLAG', 'SCORE', 'GRADE',
#        'GRADE DATE', 'RECORD DATE', 'INSPECTION TYPE', 'address_full',
#        'Address', 'cities', 'lat', 'long'],
#       dtype='object')

# %%
gkk = test.groupby(['DBA', 'BORO','CUISINE DESCRIPTION', 'GRADE','address_full','lat','long']).agg({'VIOLATION CODE':'count'}) 
gkk
# Out:
#                                                                                                                                                                       VIOLATION CODE
# DBA                                  BORO          CUISINE DESCRIPTION                                GRADE address_full                        lat       long
# 'CESCA                               MANHATTAN     Italian                                            A     166 W 75TH ST 10023.0               40.780320 -73.979927               2
# 1 OR 8                               BROOKLYN      Japanese                                           A     66 SOUTH    2 STREET 11249.0        40.714253 -73.965448               3
# 101 KENNEDY FRIED CHICKEN            QUEENS        American                                           Z     10815 101ST AVE 11419.0             40.687596 -73.835026               3
# ...

# %%
gkk = gkk.reset_index()
gkk
# Out:
#                                        DBA           BORO  \
# 0                                   'CESCA      MANHATTAN
# 1                                   1 OR 8       BROOKLYN
# 2                101 KENNEDY FRIED CHICKEN         QUEENS
# 3                                1080 BREW         QUEENS
# 4                110 KENNEDY FRIED CHICKEN  STATEN ISLAND
# 5                             120 BAY CAFE  STATEN ISLAND
# 6                            18 RESTAURANT      MANHATTAN
# 7                                     1803      MANHATTAN
# 8                             2 BROS PIZZA      MANHATTAN
# 9               2 BROS PIZZA/ CORVO COFFEE      MANHATTAN
# 10                       21 HOME'S KITCHEN      MANHATTAN
# 11                             212 HISAE'S      MANHATTAN
# 12                 21ST LIC DELI & GROCERY         QUEENS
# 13                 22 STR CONCESSION STAND       BROOKLYN
# 14                               27 MORTON      MANHATTAN
# ...

# %%
gkk.to_csv("data/Map_Marker_File.csv",index=False)
