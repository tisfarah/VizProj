# %%
import os
import pandas as pd
import numpy
import requests
import json
from pandas.io.json import json_normalize

# %% [markdown]
# https://github.com/xmunoz/sodapy
# https://dev.socrata.com/docs/queries/
# https://dev.socrata.com/foundry/data.cityofnewyork.us/43nn-pn8j
# https://data.cityofnewyork.us/Health/DOHMH-New-York-City-Restaurant-Inspection-Results/43nn-pn8j

# %%
api = "https://data.cityofnewyork.us/resource/43nn-pn8j.json?"

#this method only reads the 1000 lines
data = pd.read_json(api)
data.head()
# data.info()
# Out:
#                                             action   boro building     camis  \
# 0  Violations were cited in the following area(s).  BRONX     1007  30075445
# 1  Violations were cited in the following area(s).  BRONX     1007  30075445
# 2  Violations were cited in the following area(s).  BRONX     1007  30075445
# 3  Violations were cited in the following area(s).  BRONX     1007  30075445
# 4  Violations were cited in the following area(s).  BRONX     1007  30075445
#
#   critical_flag cuisine_description                    dba grade  \
# 0  Not Critical              Bakery  MORRIS PARK BAKE SHOP     A
# 1  Not Critical              Bakery  MORRIS PARK BAKE SHOP     A
# 2  Not Critical              Bakery  MORRIS PARK BAKE SHOP     A
# 3      Critical              Bakery  MORRIS PARK BAKE SHOP   NaN
# 4  Not Critical              Bakery  MORRIS PARK BAKE SHOP   NaN
#
#                 grade_date          inspection_date  \
# 0  2019-06-11T00:00:00.000  2019-06-11T00:00:00.000
# ...

# %%
# make sure to install these packages before running:
# pip install pandas
# pip install sodapy

import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofnewyork.us", 'zwEW3ueAw2EZe3kJXZaM0gEz5')

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofnewyork.us,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("43nn-pn8j", limit=2000,)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)

client.close()

# %%
results_df.head()
# Out:
#                                             action   boro building     camis  \
# 0  Violations were cited in the following area(s).  BRONX     1007  30075445
# 1  Violations were cited in the following area(s).  BRONX     1007  30075445
# 2  Violations were cited in the following area(s).  BRONX     1007  30075445
# 3  Violations were cited in the following area(s).  BRONX     1007  30075445
# 4  Violations were cited in the following area(s).  BRONX     1007  30075445
#
#   critical_flag cuisine_description                    dba grade  \
# 0  Not Critical              Bakery  MORRIS PARK BAKE SHOP     A
# 1  Not Critical              Bakery  MORRIS PARK BAKE SHOP     A
# 2  Not Critical              Bakery  MORRIS PARK BAKE SHOP     A
# 3      Critical              Bakery  MORRIS PARK BAKE SHOP   NaN
# 4  Not Critical              Bakery  MORRIS PARK BAKE SHOP   NaN
#
#                 grade_date          inspection_date  \
# 0  2019-06-11T00:00:00.000  2019-06-11T00:00:00.000
# ...
